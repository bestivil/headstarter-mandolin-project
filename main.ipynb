# %% [markdown]
# # Setting up the notebook

# %%
pip install google-generativeai httpx pydantic PyMuPDF pdfplumber pytesseract ocrmypdf

# %%
import httpx
import os
import asyncio
import time
import json
import logging

import concurrent.futures

from typing import Dict, List, Any, Optional, Tuple
from pathlib import Path
import re
from datetime import datetime
import pathlib
import fitz
from pydantic import BaseModel, Field

import subprocess
import pdfplumber
import pytesseract
from PIL import Image

import google.generativeai as genai

# %%
gemini_client = genai.configure(api_key=os.getenv('GOOGLE_API_KEY'))
gemini_model = "gemini-2.5-flash-lite-preview-06-17"

# %%
person_name = "Amy"

input_pdf = f"Input Data/{person_name}/referral_package.pdf"
searchable_pdf = f"Input Data/{person_name}/generated/referral_package_searchable.pdf"
input_pa_form = f"Input Data/{person_name}/PA.pdf"
output_pa_form = f"Output Data/{person_name}/PA_filled.pdf"
lang = "eng"

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %% [markdown]
# # Extracting data from the Referral Form using OCR

# %%
# Uses OCRmyPDF to apply an OCR layer to a scanned PDF, return both extracted text and image-based OCR
# these values are used to generate a prompt for the Gemini model to answer the questions

def apply_ocrmypdf_to_input_pdf(input_pdf: str, output_pdf: str, lang: str = "eng"):
    os.makedirs(os.path.dirname(output_pdf), exist_ok=True)
    
    subprocess.run(
        [
            "ocrmypdf",
            "--language", 
            lang,
            "--deskew",
            "--rotate-pages",
            input_pdf,
            output_pdf,
        ],
        check=True,
    )

# %%
# Function to extract text from a searchable PDF using pdfplumber 
# and OCR on each page image using pytesseract and return a dictionary of pages with the text
pages: dict[str, dict[str, str]] = {}

def extract_text_searchable(pdf_path: str):
    """Extract text from a searchable PDF using pdfplumber."""
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages, 1):
            text = page.extract_text() or ""
            if "Page " + str(i) not in pages:
                pages["Page " + str(i)] = {"pdfplumber": "", "ocr": ""}
            pages["Page " + str(i)]["pdfplumber"] = text


def ocr_images_from_pdf(pdf_path: str, lang: str = "eng", dpi: int = 300):
    """Perform OCR on each PDF page image using pytesseract."""
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages, 1):
            pil_img = page.to_image(resolution=dpi).original
            gray = pil_img.convert("L").point(lambda x: 0 if x < 128 else 255)
            text = pytesseract.image_to_string(gray, lang=lang)
            if "Page " + str(i) not in pages:
                pages["Page " + str(i)] = {"pdfplumber": "", "ocr": ""}
            pages["Page " + str(i)]["ocr"] = text

# %%
apply_ocrmypdf_to_input_pdf(input_pdf, searchable_pdf, lang)
# Out:
# Start processing 8 pages concurrently
#     7 page is facing ⇧, confidence 10.10 - no change
#     8 page is facing ⇧, confidence 9.24 - no change
#     6 page is facing ⇧, confidence 11.78 - no change
#     3 page is facing ⇧, confidence 15.14 - rotation appears correct
#     2 page is facing ⇧, confidence 11.38 - no change
#     5 page is facing ⇧, confidence 14.18 - rotation appears correct
#     4 page is facing ⇧, confidence 12.99 - no change
#     1 page is facing ⇧, confidence 21.19 - rotation appears correct
#     9 page is facing ⇧, confidence 15.27 - rotation appears correct
# Postprocessing...
# Image optimization ratio: 1.19 savings: 15.7%
# Total file size ratio: 1.83 savings: 45.3%
# Output file is a PDF/A-2B (as expected)

# %%
with concurrent.futures.ThreadPoolExecutor(max_workers=2) as exe:
        fut1 = exe.submit(extract_text_searchable, searchable_pdf)
        fut2 = exe.submit(ocr_images_from_pdf, input_pdf, "eng")
        concurrent.futures.wait([fut1, fut2])

# %% [markdown]
# # Extracting the fields from PA Form

# %%
def extract_fields_with_positions(pdf_path):
    doc = fitz.open(pdf_path)
    fields = []
    for page_num, page in enumerate(doc, start=1):
        for w in page.widgets() or []:
            field = {
                "name": w.field_name,
                "type": "checkbox" if w.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX else "text",
                "value": w.field_value,
                "page": page_num,
                "field_type": w.field_type,
                "field_type_string": w.field_type_string,
                "field_label": w.field_label,
            }

            print(field)
            fields.append(field)

    fields_by_page = {}
    for field in fields:
        page_num = field['page']
        if page_num not in fields_by_page:
            fields_by_page[page_num] = []
        fields_by_page[page_num].append(field)
    return fields_by_page

# %%
pa_page_fields = extract_fields_with_positions(input_pa_form)

# %% [markdown]
# ## Using Gemini to get PA form contexts

# %%
def form_pa_prompt(pa_fields):
    return f"""You are an expert medical document processing assistant specializing in Prior Authorization (PA) forms.
Given Input:
1. A list of PA fields (name, type, page, label, current value)
2. The full PA form PDF

Task:
For each field in page order:
1. Infer the explicit question:
   – Checkbox → yes/no question
   – Text → information request
   – Date → specify the referenced event/action
2. Generate concise (≤25 words) context including:
   section/category, primary vs. sub-question, whose data (patient/provider/insurer),
   any dependencies/conditional logic, clinical relevance
3. Preserve parent-child relationships and logical flow

Critical Requirements:
- Every field must have both question and context added
- Context must be specific and clinically relevant
- Maintain logical relationships between fields
- Preserve exact field names and labels
- Keep context concise but informative (25 words max)

IMPORTANT: RESPONSE FORMAT
Each output JSON object must only contain the fields name, type, page,
field_label, question, context in this format:
{{'name': 'CB1', 'type': 'checkbox', 'page': 2,
  'field_label': 'Start of treatment',
  'question': 'Is this a new treatment start for the patient?',
  'context': 'Initial checkbox in treatment timeline indicating whether patient begins new therapy.'}},
{{'name': 'T2', 'type': 'text', 'page': 2,
  'field_label': 'Start date: (MM)',
  'question': 'What is the treatment start date (MM)?',
  'context': 'Captures the calendar month when treatment commenced for scheduling.'}}

<PA_FORM_DATA>
{pa_fields}
</PA_FORM_DATA>

Only output valid JSON."""

# %%
from google import genai
from google.genai import types

client = genai.Client()

async def query_gemini_async(
    prompt: str,
    pdf_path: str,
    model: str = gemini_model,
) -> str:
    filepath = pathlib.Path(pdf_path)

    loop = asyncio.get_event_loop()
    response = await loop.run_in_executor(
        None,
        lambda: client.models.generate_content(
            model=model,
            contents=[
                types.Part.from_bytes(
                    data=filepath.read_bytes(),
                    mime_type="application/pdf",
                ),
                prompt,
            ],
        ),
    )

    return response.text or ""

pa_fields_with_context: dict[int, str] = {}

async def process_page(page: int):
    prompt = form_pa_prompt(pa_page_fields[page])

    result = await query_gemini_async(
        prompt,
        pdf_path=input_pa_form,
    )
    return page, result

tasks = [process_page(page) for page in pa_page_fields]
results = await asyncio.gather(*tasks)
for page, result in results:
    pa_fields_with_context[page] = result

# %%
from google import genai
from google.genai import types
client = genai.Client()

class PAFormAnswer(BaseModel):
    name: str
    page: int
    field_label: str
    answer: str = Field(
        description="answer to the question based on the referral package PDF"
    )


def query_gemini_for_answers(prompt, referral_package, model=gemini_model):
    referral_package_filepath = pathlib.Path(referral_package)

    response = client.models.generate_content(
        model=model,
        contents=[
            types.Part.from_bytes(
                data=referral_package_filepath.read_bytes(),
                mime_type='application/pdf',
            ),
            
            prompt
        ],
        config={
            "response_mime_type": "application/json",
            "response_schema": list[PAFormAnswer],
        }
    )

    return response.text

# %%
referral_package_prompt = """You are an expert medical document processing assistant specializing in prior authorization (PA) forms and medical documentation. You are given a list of PA form fields with their associated context and questions. Your task is to thoroughly analyze the provided PDF referral package and extract all relevant information to accurately fill out the PA form.

Please follow these guidelines:
1. Carefully review each field in the <PA_FORM_DATA> and understand its requirements
2. Extract exact dates, diagnoses, medications, dosages, and other clinical details from the referral package to fill out the <PA_FORM_DATA>
Use the OCR_EXTRACTED_TEXT to help you find the information you need & answer the questions correctly. It is important to override OCR_EXTRACTED_TEXT if a better answer is available.
3. Match the extracted information to the corresponding PA form fields
4. Pay special attention to:
   - Patient demographics and insurance information
   - Current diagnoses and ICD-10 codes
   - Medication details (name, strength, frequency, duration)
   - Previous treatments and their outcomes
   - Clinical assessments and test results
   - Provider information and signatures
5. If information is missing or unclear, indicate this explicitly
6. Format dates as MM/DD/YYYY unless otherwise specified
7. Use exact values and terminology from source documents when possible

<PA_FORM_DATA>
""" + str(pa_fields_with_context) + """
</PA_FORM_DATA>

<OCR_EXTRACTED_TEXT>
""" + str(pages) + """
</OCR_EXTRACTED_TEXT>

## IMPORTANT: RESPONSE FORMAT

FOR CHECKBOXES:
- They must be ALWAYS filled out with "Yes" or "No"

Each output JSON object should only contain the fields – name, page, field_label, answer – in the following format:
{'name': 'CB1', 'page': 2, 'field_label': 'Start of treatment', 'answer': 'answer to the question based on the referral package PDF'},
{'name': 'T2',   'page': 2, 'field_label': 'Start date: (MM)',   'answer': 'answer to the question based on the referral package PDF'}

Note: The Request Completed By field should always have today's date in the format MM/DD/YYYY

"""

# %%
pa_form_answers = query_gemini_for_answers(
referral_package_prompt,
    input_pdf,
    model=gemini_model
)
# Out:
# 2025-06-22 23:23:09,502 - INFO - AFC is enabled with max remote calls: 10.
# 2025-06-22 23:23:32,647 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite-preview-06-17:generateContent "HTTP/1.1 200 OK"
# 2025-06-22 23:23:32,669 - INFO - AFC remote call 1 is done.

# %%
print(pa_form_answers)
# Out:
# [
#   {
#     "name": "T1",
#     "page": 1,
#     "field_label": "Date:",
#     "answer": "04/08/2023"
#   },
#   {
#     "name": "T2",
#     "page": 1,
#     "field_label": "To:",
#     "answer": "Foresight Health"
#   },
#   {
#     "name": "T3",
#     "page": 1,
#     "field_label": "Re:",
#     "answer": "Amy Chen"
#   },
#   {
#     "name": "T4",
#     "page": 1,
#     "field_label": "Attention:",
#     "answer": "UT Neurology"
#   },
#   {
#     "name": "T5",
#     "page": 1,
#     "field_label": "From:",
#     "answer": "UT Neurology Angela Nicole NPC/Catherine CMA"
#   },
#   {
#     "name": "T6",
#     "page": 2,
#     "field_label": "Patient Name",
#     "answer": "Chen, Amy"
#   },
#   {
#     "name": "T7",
#     "page": 2,
#     "field_label": "Date of Birth",
#     "answer": "05/23/1983"
#   },
#   {
#     "name": "T8",
#     "page": 2,
#     "field_label": "Age",
#     "answer": "39 y.o."
#   },
#   {
#     "name": "T9",
#     "page": 2,
#     "field_label": "Social Security Number",
#     "answer": "xxx-xx-8110"
#   },
#   {
#     "name": "T10",
#     "page": 2,
#     "field_label": "Sex",
#     "answer": "Female"
#   },
#   {
#     "name": "T11",
#     "page": 2,
#     "field_label": "Language",
#     "answer": "English"
#   },
#   {
#     "name": "T12",
#     "page": 2,
#     "field_label": "Admitting Provider",
#     "answer": "UT Neurology"
#   },
#   {
#     "name": "T13",
#     "page": 2,
#     "field_label": "Admission Date/Time",
#     "answer": "Not on file"
#   },
#   {
#     "name": "T14",
#     "page": 2,
#     "field_label": "Expected Length of Stay",
#     "answer": "Never Admitted"
#   },
#   {
#     "name": "T15",
#     "page": 2,
#     "field_label": "Length of Stay",
#     "answer": "0h"
#   },
#   {
#     "name": "T16",
#     "page": 2,
#     "field_label": "Discharge Provider",
#     "answer": "Not on file"
#   },
#   {
#     "name": "T17",
#     "page": 2,
#     "field_label": "Discharge Date",
#     "answer": "Not on file"
#   },
#   {
#     "name": "T18",
#     "page": 2,
#     "field_label": "Discharge Disposition",
#     "answer": "Not on file"
#   },
#   {
#     "name": "T19",
#     "page": 2,
#     "field_label": "Discharge Destination",
#     "answer": "Not on file"
#   },
#   {
#     "name": "T20",
#     "page": 2,
#     "field_label": "Attending Provider:",
#     "answer": "(none)"
#   },
#   {
#     "name": "T21",
#     "page": 2,
#     "field_label": "Isolation",
#     "answer": "None"
#   },
#   {
#     "name": "T22",
#     "page": 2,
#     "field_label": "Infection",
#     "answer": "None"
#   },
#   {
#     "name": "T23",
#     "page": 2,
#     "field_label": "Ht:",
#     "answer": "--"
#   },
#   {
#     "name": "T24",
#     "page": 2,
#     "field_label": "Wt:",
#     "answer": "50.9 kg"
#   },
#   {
#     "name": "T25",
#     "page": 2,
#     "field_label": "Admission Cmt:",
#     "answer": "None"
#   },
#   {
#     "name": "T26",
#     "page": 2,
#     "field_label": "Principal Problem:",
#     "answer": "None"
#   },
#   {
#     "name": "T27",
#     "page": 2,
#     "field_label": "Allergies:",
#     "answer": "No Known Allergies"
#   },
#   {
#     "name": "T28",
#     "page": 2,
#     "field_label": "Code Status:",
#     "answer": "Not on file"
#   },
#   {
#     "name": "T29",
#     "page": 2,
#     "field_label": "Address",
#     "answer": "2751 Market DR HILLDALE TN 37253-2973"
#   },
#   {
#     "name": "T30",
#     "page": 2,
#     "field_label": "Phone Numbers",
#     "answer": "Hm: 615-593-1048 Cell: 615-593-1048"
#   },
#   {
#     "name": "T31",
#     "page": 2,
#     "field_label": "Insurance Information",
#     "answer": "ABS OF TN"
#   },
#   {
#     "name": "T32",
#     "page": 2,
#     "field_label": "Religion",
#     "answer": "Unknown"
#   },
#   {
#     "name": "T33",
#     "page": 2,
#     "field_label": "Date Of Birth",
#     "answer": "5/23/1983"
#   },
#   {
#     "name": "T34",
#     "page": 2,
#     "field_label": "Gender Identity",
#     "answer": "Female"
#   },
#   {
#     "name": "T35",
#     "page": 2,
#     "field_label": "Race",
#     "answer": "Asian"
#   },
#   {
#     "name": "T36",
#     "page": 2,
#     "field_label": "Ethnic Group",
#     "answer": "Not Hispanic, Latino/a, or Spanish origin"
#   },
#   {
#     "name": "T37",
#     "page": 2,
#     "field_label": "Preferred Language",
#     "answer": "English, Mandarin"
#   },
#   {
#     "name": "T38",
#     "page": 2,
#     "field_label": "Preferred Written Language",
#     "answer": "English, Mandarin"
#   },
#   {
#     "name": "T39",
#     "page": 2,
#     "field_label": "Hospital Account",
#     "answer": "Not on file"
#   },
#   {
#     "name": "T40",
#     "page": 2,
#     "field_label": "Problem List",
#     "answer": "Migraines\nDifficulty falling or staying asleep\nAltitude sickness preventative measures\nNeck pain"
#   },
#   {
#     "name": "T41",
#     "page": 3,
#     "field_label": "Encounter Date",
#     "answer": "04/01/2023"
#   },
#   {
#     "name": "T42",
#     "page": 3,
#     "field_label": "Patient Name",
#     "answer": "Chen, Amy"
#   },
#   {
#     "name": "T43",
#     "page": 3,
#     "field_label": "MRN",
#     "answer": "01051001"
#   },
#   {
#     "name": "T44",
#     "page": 3,
#     "field_label": "DOB",
#     "answer": "05/23/1983"
#   },
#   {
#     "name": "T45",
#     "page": 3,
#     "field_label": "Procedure visit",
#     "answer": "4/1/2023 EMG Neurology"
#   },
#   {
#     "name": "T46",
#     "page": 3,
#     "field_label": "Provider",
#     "answer": "Angela Nicole, NP (Neurology)"
#   },
#   {
#     "name": "T47",
#     "page": 3,
#     "field_label": "Primary diagnosis",
#     "answer": "Intractable chronic migraine without aura and with status migrainosus"
#   },
#   {
#     "name": "T48",
#     "page": 3,
#     "field_label": "Reason for Visit",
#     "answer": "Botulinum Toxin Injection"
#   },
#   {
#     "name": "T49",
#     "page": 3,
#     "field_label": "Progress Notes",
#     "answer": "Angela Nicole, NP (Nurse Practitioner) Neurology"
#   },
#   {
#     "name": "T50",
#     "page": 3,
#     "field_label": "Name",
#     "answer": "Amy Chen"
#   },
#   {
#     "name": "T51",
#     "page": 3,
#     "field_label": "MRN",
#     "answer": "01051001"
#   },
#   {
#     "name": "T52",
#     "page": 3,
#     "field_label": "DOB",
#     "answer": "5/23/1983"
#   },
#   {
#     "name": "T53",
#     "page": 3,
#     "field_label": "PROCEDURE:",
#     "answer": "Botox for chronic migraine"
#   },
#   {
#     "name": "T54",
#     "page": 3,
#     "field_label": "HISTORY:",
#     "answer": "The patient presents with a history of chronic migraines for Botox injections. Prior to the procedure, the consent process was completed, including a discussion of the overall benefits and addressing any questions. The patient confirmed their understanding and expressed readiness to proceed with the injections."
#   },
#   {
#     "name": "T55",
#     "page": 3,
#     "field_label": "PROCEDURE:",
#     "answer": "Each vial of botulinum toxin type A (BOTOX) was diluted with 1.5 cc of preservative-free saline, and a 32-gauge, 0.5-inch needle was used for the injections. The patient was positioned comfortably in an upright seated posture. Each injection site was cleansed with alcohol, and a topical numbing spray was applied to anesthetize the area."
#   },
#   {
#     "name": "T56",
#     "page": 3,
#     "field_label": "Injection sites and units:",
#     "answer": "10 units into the right frontalis (administered as two 5-unit injections)\n10 units into the left frontalis (administered as two 5-unit injections)\n5 units into the right corrugator\n5 units into the left corrugator\n10 units into the right occipitalis (in 3 5 unit injections)\n10 units into the left occipitalis (in 3 5 units injections)\n5 units into the right cervical paraspinal muscles (in 2 5 unit injections)\n5 units into the left cervical paraspinal muscles (in 2 5 unit injections)"
#   },
#   {
#     "name": "T57",
#     "page": 4,
#     "field_label": "Injection sites and units:",
#     "answer": "30 units into the right trapezius (in 3 10 unit injections)\n30 units into the left trapezius (in 3 10 unit injections)"
#   },
#   {
#     "name": "T58",
#     "page": 4,
#     "field_label": "SAMPLE",
#     "answer": "A total of 190 units were drawn up and utilized and there was a total wastage of 10 units."
#   },
#   {
#     "name": "T59",
#     "page": 4,
#     "field_label": "Lot #:",
#     "answer": "C1801AC1"
#   },
#   {
#     "name": "T60",
#     "page": 4,
#     "field_label": "Expiration Date:",
#     "answer": "04/2025"
#   },
#   {
#     "name": "T61",
#     "page": 4,
#     "field_label": "Provider:",
#     "answer": "Angela Nicole, NP"
#   },
#   {
#     "name": "T62",
#     "page": 4,
#     "field_label": "Progress Notes Provider:",
#     "answer": "Amy Rains, NP (Nurse Practitioner) Neurology"
#   },
#   {
#     "name": "T63",
#     "page": 4,
#     "field_label": "Patient ID:",
#     "answer": "Amy Chen is a 39 y.o. female."
#   },
#   {
#     "name": "T64",
#     "page": 4,
#     "field_label": "INTERVAL HISTORY:",
#     "answer": "Patient was last seen 2/24/2023 via telemedicine with Dr. Fazal at which time she was to continue Zomig PRN and Nurtec every other day. She is here today to restart Botox for prevention. Today she reports she had been off Aimovig since December. She had some improvement with Botox/cosmetic. The last few month have been difficult: back to chronic daily HA."
#   },
#   {
#     "name": "T65",
#     "page": 4,
#     "field_label": "Nurtec:",
#     "answer": "every other day (preventive)"
#   },
#   {
#     "name": "T66",
#     "page": 4,
#     "field_label": "Zomig:",
#     "answer": "stopped keeping track: increased frequency/severity"
#   },
#   {
#     "name": "T67",
#     "page": 4,
#     "field_label": "Vyepti:",
#     "answer": "she would like to do this vs. Botox"
#   },
#   {
#     "name": "T68",
#     "page": 4,
#     "field_label": "Medications:",
#     "answer": "Propranolol\nVerapamil\nTopiramate (Topamax)\nNortriptyline\nVenlafaxine (Effexor)\nGabapentin"
#   },
#   {
#     "name": "T69",
#     "page": 5,
#     "field_label": "Medications:",
#     "answer": "Skelaxin with indomethacin\nNerve blocks\nOral contraceptives\nMagnesium\nFeverfew\nButterburr\nAbortives:\nZomig\nFrova\nImitrex\nFioricet\nZofran"
#   },
#   {
#     "name": "T70",
#     "page": 5,
#     "field_label": "Review of Systems",
#     "answer": "Musculoskeletal: Positive for arthralgias.\nNeurological: Positive for headaches.\nPsychiatric/Behavioral: Positive for agitation.\nAll other systems reviewed and are negative."
#   },
#   {
#     "name": "T71",
#     "page": 5,
#     "field_label": "Neurologic Exam - Mental Status",
#     "answer": "Oriented to person, place, and time.\nOriented to person.\nOriented to place.\nAttention: normal. Concentration: normal.\nSpeech: speech is normal\nLevel of consciousness: alert\nKnowledge: good.\nNormal comprehension."
#   },
#   {
#     "name": "T72",
#     "page": 5,
#     "field_label": "Cranial Nerves",
#     "answer": "Cranial nerves II through XII intact.\nCN III, IV, VI\nPupils are equal, round, and reactive to light."
#   },
#   {
#     "name": "T73",
#     "page": 5,
#     "field_label": "Motor Exam",
#     "answer": "Muscle bulk: normalMoves all extremities symmetrically"
#   },
#   {
#     "name": "T74",
#     "page": 5,
#     "field_label": "Gait, Coordination, and Reflexes",
#     "answer": "Gait is intact."
#   },
#   {
#     "name": "T75",
#     "page": 6,
#     "field_label": "Gait:",
#     "answer": "normal"
#   },
#   {
#     "name": "T76",
#     "page": 6,
#     "field_label": "Coordination:",
#     "answer": "Finger to nose coordination: normal"
#   },
#   {
#     "name": "T77",
#     "page": 6,
#     "field_label": "Physical Exam - Vitals reviewed.",
#     "answer": "BP 107/50 (Abnormal)"
#   },
#   {
#     "name": "T78",
#     "page": 6,
#     "field_label": "Physical Exam - Constitutional",
#     "answer": "Appearance: Normal appearance. She is well-developed."
#   },
#   {
#     "name": "T79",
#     "page": 6,
#     "field_label": "Physical Exam - HENT",
#     "answer": "Head: Normocephalic and atraumatic."
#   },
#   {
#     "name": "T80",
#     "page": 6,
#     "field_label": "Physical Exam - Eyes",
#     "answer": "Pupils: Pupils are equal, round, and reactive to light."
#   },
#   {
#     "name": "T81",
#     "page": 6,
#     "field_label": "Physical Exam - Pulmonary",
#     "answer": "Effort: Pulmonary effort is normal."
#   },
#   {
#     "name": "T82",
#     "page": 6,
#     "field_label": "Physical Exam - Musculoskeletal",
#     "answer": "General: Normal range of motion."
#   },
#   {
#     "name": "T83",
#     "page": 6,
#     "field_label": "Physical Exam - Skin",
#     "answer": "General: Skin is warm and dry."
#   },
#   {
#     "name": "T84",
#     "page": 6,
#     "field_label": "Physical Exam - Neurological",
#     "answer": "General: No focal deficit present.\nMental Status: She is alert and oriented to person, place, and time. Mental status is at baseline.\nCranial Nerves: Cranial nerves 2-12 are intact.\nCoordination: Finger-Nose-Finger Test normal.\nGait: Gait is intact."
#   },
#   {
#     "name": "T85",
#     "page": 6,
#     "field_label": "Physical Exam - Psychiatric",
#     "answer": "Mood and Affect: Mood normal.\nSpeech: Speech normal.\nBehavior: Behavior normal.\nThought Content: Thought content normal."
#   },
#   {
#     "name": "T86",
#     "page": 6,
#     "field_label": "Assessment",
#     "answer": "Diagnoses and all orders for this visit:\nIntractable chronic migraine without aura and with status migrainosus\nketorolac (TORADOL) injection 30 mg\nPrimary insomnia\nCervicalgia"
#   },
#   {
#     "name": "T87",
#     "page": 6,
#     "field_label": "Current Treatment Status",
#     "answer": "She has been using Nutrec more for prevention with some improvement along with cosmetic botox. She has had more migraines the last few weeks. She is taking Zomig PRN. She would like to consider adding Vyepti (over Botox) if the insurance will approve."
#   },
#   {
#     "name": "T88",
#     "page": 7,
#     "field_label": "Botox today:",
#     "answer": "SAMPLE Used"
#   },
#   {
#     "name": "T89",
#     "page": 7,
#     "field_label": "For prevention:",
#     "answer": "--nutrec 75 mg every other day"
#   },
#   {
#     "name": "T90",
#     "page": 7,
#     "field_label": "Future:",
#     "answer": "consider restart of Aimovig"
#   },
#   {
#     "name": "T91",
#     "page": 7,
#     "field_label": "Work on Vyepti infusion approval:",
#     "answer": "prefers close to home"
#   },
#   {
#     "name": "T92",
#     "page": 7,
#     "field_label": "Headache stoplight - Green light:",
#     "answer": "alleve, caffeine, sugar"
#   },
#   {
#     "name": "T93",
#     "page": 7,
#     "field_label": "Headache stoplight - Yellow light:",
#     "answer": "Nutrec 75 mg at onset. Can repeat in 24 hours. If she has already taken Nutrec, she could use Naproxen at this phase."
#   },
#   {
#     "name": "T94",
#     "page": 7,
#     "field_label": "Headache stoplight - Red light:",
#     "answer": "zomig 2.5-5 mg at onset. Can repeat in 4 hours if needed."
#   },
#   {
#     "name": "T95",
#     "page": 7,
#     "field_label": "Other medications:",
#     "answer": "She can continue medrol dosepack if in status migrainosus; can consider depakote bridge\nContinue Naproxen 550 mg prn for neck pain.\nFor insomnia, continue klonopin 0.25 mg at bedtime."
#   },
#   {
#     "name": "T96",
#     "page": 7,
#     "field_label": "RTC:",
#     "answer": "in August"
#   },
#   {
#     "name": "T97",
#     "page": 7,
#     "field_label": "Total time:",
#     "answer": "35 minutes"
#   },
#   {
#     "name": "T98",
#     "page": 7,
#     "field_label": "Instructions - Return",
#     "answer": "in about 5 months (around 9/1/2023)."
#   },
#   {
#     "name": "T99",
#     "page": 7,
#     "field_label": "Instructions - Vyepti",
#     "answer": "We will call you regarding the Vyepti infusion"
#   },
#   {
#     "name": "T100",
#     "page": 7,
#     "field_label": "Instructions - Botox",
#     "answer": "will peak in 2 weeks"
#   },
#   {
#     "name": "T101",
#     "page": 7,
#     "field_label": "Return",
#     "answer": "in 5 months"
#   },
#   {
#     "name": "T102",
#     "page": 7,
#     "field_label": "Vitals:",
#     "answer": "BP 107/50 ! (Abnormal) (BP Location: Right arm, Patient Position: Sitting, BP Cuff Size: Adult)\nPulse 73 Temp 37.4 °C (Forehead) Wt 50.9 kg BMI 21.85 kg/m? BSA 1.63 m? Pain Sc 0-No pain"
#   },
#   {
#     "name": "T103",
#     "page": 7,
#     "field_label": "Communications",
#     "answer": "Chart Routed to Ellen Valadez, MD"
#   },
#   {
#     "name": "T104",
#     "page": 8,
#     "field_label": "Medication",
#     "answer": "ketorolac (TORADOL) injection 30 mg"
#   },
#   {
#     "name": "T105",
#     "page": 8,
#     "field_label": "Admin Date",
#     "answer": "04/01/2023"
#   },
#   {
#     "name": "T106",
#     "page": 8,
#     "field_label": "Action",
#     "answer": "Given"
#   },
#   {
#     "name": "T107",
#     "page": 8,
#     "field_label": "Dose",
#     "answer": "30 mg"
#   },
#   {
#     "name": "T108",
#     "page": 8,
#     "field_label": "Route",
#     "answer": "intramuscular"
#   },
#   {
#     "name": "T109",
#     "page": 8,
#     "field_label": "Administered By",
#     "answer": "Cynthia Cagle, LPN"
#   },
#   {
#     "name": "T110",
#     "page": 8,
#     "field_label": "Medication",
#     "answer": "ketorolac 30 mg/mL (1 mL) solution"
#   },
#   {
#     "name": "T111",
#     "page": 8,
#     "field_label": "NDC",
#     "answer": "0358-23072-65"
#   },
#   {
#     "name": "T112",
#     "page": 8,
#     "field_label": "Lot#",
#     "answer": "10000181"
#   },
#   {
#     "name": "T113",
#     "page": 8,
#     "field_label": "Expiration Date",
#     "answer": "10/30/2024"
#   },
#   {
#     "name": "T114",
#     "page": 8,
#     "field_label": "Manufacturer",
#     "answer": "BAXTER HEALTHCA"
#   },
#   {
#     "name": "T115",
#     "page": 8,
#     "field_label": "Qty",
#     "answer": "1"
#   },
#   {
#     "name": "T116",
#     "page": 8,
#     "field_label": "Size",
#     "answer": "1 mL"
#   },
#   {
#     "name": "T117",
#     "page": 8,
#     "field_label": "Billing Code",
#     "answer": "1"
#   },
#   {
#     "name": "T118",
#     "page": 8,
#     "field_label": "Added:",
#     "answer": "eptinezumab-jjmr (VYEPTI) 100 mg/mL solution"
#   },
#   {
#     "name": "T119",
#     "page": 8,
#     "field_label": "Refills",
#     "answer": "0"
#   },
#   {
#     "name": "T120",
#     "page": 8,
#     "field_label": "Start Date",
#     "answer": "4/1/2023"
#   },
#   {
#     "name": "T121",
#     "page": 8,
#     "field_label": "End Date",
#     "answer": "4/1/2023"
#   },
#   {
#     "name": "T122",
#     "page": 8,
#     "field_label": "Infusion details",
#     "answer": "Infuse 1 mL (100 mg total) into a venous catheter once for 1 dose. - intravenous"
#   },
#   {
#     "name": "T123",
#     "page": 8,
#     "field_label": "Prior authorization:",
#     "answer": "Approved"
#   },
#   {
#     "name": "T124",
#     "page": 8,
#     "field_label": "Medication List at End of Visit - Medication",
#     "answer": "clonazePAM (KlonoPIN) 0.5 mg tablet"
#   },
#   {
#     "name": "T125",
#     "page": 8,
#     "field_label": "Refills",
#     "answer": "5"
#   },
#   {
#     "name": "T126",
#     "page": 8,
#     "field_label": "Start Date",
#     "answer": "09/23/2022"
#   },
#   {
#     "name": "T127",
#     "page": 8,
#     "field_label": "End Date",
#     "answer": "5/1/2023"
#   },
#   {
#     "name": "T128",
#     "page": 8,
#     "field_label": "Medication",
#     "answer": "eptinezumab-jjmr (VYEPTI) 100 mg/mL solution"
#   },
#   {
#     "name": "T129",
#     "page": 8,
#     "field_label": "Refills",
#     "answer": "0"
#   },
#   {
#     "name": "T130",
#     "page": 8,
#     "field_label": "Start Date",
#     "answer": "5/1/2023"
#   },
#   {
#     "name": "T131",
#     "page": 8,
#     "field_label": "End Date",
#     "answer": "5/1/2023"
#   },
#   {
#     "name": "T132",
#     "page": 8,
#     "field_label": "Infusion details",
#     "answer": "Infuse 1 mL (100 mg total) into a venous catheter once for 1 dose. - intravenous"
#   },
#   {
#     "name": "T133",
#     "page": 8,
#     "field_label": "Prior authorization:",
#     "answer": "Approved"
#   },
#   {
#     "name": "T134",
#     "page": 8,
#     "field_label": "Medication",
#     "answer": "methylPREDNISolone (MEDROL DOSEPACK) 4 mg tablet"
#   },
#   {
#     "name": "T135",
#     "page": 8,
#     "field_label": "Start Date",
#     "answer": "6/15/2022"
#   },
#   {
#     "name": "T136",
#     "page": 8,
#     "field_label": "Medication",
#     "answer": "naproxen sodium (ANAPROX) 550 mg tablet"
#   },
#   {
#     "name": "T137",
#     "page": 8,
#     "field_label": "Refills",
#     "answer": "11"
#   },
#   {
#     "name": "T138",
#     "page": 8,
#     "field_label": "Start Date",
#     "answer": "12/9/2021"
#   },
#   {
#     "name": "T139",
#     "page": 8,
#     "field_label": "Medication",
#     "answer": "naproxen sodium (ANAPROX) 550 mg tablet"
#   },
#   {
#     "name": "T140",
#     "page": 8,
#     "field_label": "Refills",
#     "answer": "11"
#   },
#   {
#     "name": "T141",
#     "page": 8,
#     "field_label": "Start Date",
#     "answer": "12/9/2021"
#   },
#   {
#     "name": "T142",
#     "page": 8,
#     "field_label": "Medication",
#     "answer": "rimegepant (Nurtec ODT) 75 mg tablet,disintegrating"
#   },
#   {
#     "name": "T143",
#     "page": 8,
#     "field_label": "Refills",
#     "answer": "11"
#   },
#   {
#     "name": "T144",
#     "page": 8,
#     "field_label": "Start Date",
#     "answer": "10/20/2022"
#   },
#   {
#     "name": "T145",
#     "page": 8,
#     "field_label": "Medication instructions",
#     "answer": "Take 75 mg by mouth as needed (migraine. Max 1 in 24 hours). - oral"
#   },
#   {
#     "name": "T146",
#     "page": 8,
#     "field_label": "Prior authorization status",
#     "answer": "No prior authorization was found for this prescription. Found prior authorization for another prescription for the same medication: Closed - Prior Authorization not required for patient/medication"
#   },
#   {
#     "name": "T147",
#     "page": 9,
#     "field_label": "Medication",
#     "answer": "ZOLMitriptan (ZOMIG) 5 mg tablet"
#   },
#   {
#     "name": "T148",
#     "page": 9,
#     "field_label": "Refills",
#     "answer": "11"
#   },
#   {
#     "name": "T149",
#     "page": 9,
#     "field_label": "Start Date",
#     "answer": "3/18/2023"
#   },
#   {
#     "name": "T150",
#     "page": 9,
#     "field_label": "Medication instructions",
#     "answer": "TAKE 1 TABLET BY MOUTH AT ONSET OF MIGRAINE. MAY REPEAT 1 TIME IN 4 HOURS IF NO RELIEF"
#   },
#   {
#     "name": "T151",
#     "page": 9,
#     "field_label": "Medications Administered",
#     "answer": "ketorolac tromethamine 30 mg"
#   },
#   {
#     "name": "T152",
#     "page": 9,
#     "field_label": "Visit Diagnoses",
#     "answer": "Primary: Intractable chronic migraine without aura and with status migrainosus G43.711\nPrimary insomnia F51.01\nCervicalgia M54.2"
#   }
# ]

# %%
from io import BytesIO
import fitz

YES_WORDS = {"yes", "true", "on", "1", "checked"}

def is_checked(val) -> bool:
    return str(val).strip().lower() in YES_WORDS


def fill_pa_form(pdf_path, field_mapping, out_path):
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    
    doc = fitz.open(pdf_path)

    for page in doc:
        for w in page.widgets() or []:
            data = field_mapping.get(w.field_name)
            if data is None:
                continue


            val = data["value"] if isinstance(data, dict) else data

            if data['field_type'] == 'checkbox':
                on_token = w.on_state() or "Yes"
                w.field_value = on_token if is_checked(val) else "Off"
            else:
                w.field_value = str(val)

            w.update()                


    if out_path:
        doc.save(out_path,
                 deflate=True,
                 incremental=False,
                 encryption=fitz.PDF_ENCRYPT_KEEP)
        doc.close()
    else:
        buf = BytesIO()
        doc.save(buf,
                 deflate=True,
                 incremental=False,
                 encryption=fitz.PDF_ENCRYPT_KEEP)
        buf.seek(0)
        doc.close()
        return buf

# %%
import json
 
if isinstance(pa_form_answers, str):
    pa_form_answers = json.loads(pa_form_answers)

print(pa_page_fields.items())
answer_map = {(a["page"], a["name"]): a["answer"] for a in pa_form_answers}


field_mapping = {}

for page_no, page_fields in pa_page_fields.items():
    for fld in page_fields:
        ans = answer_map.get((page_no, fld["name"]))
        
        if ans is None or ans == 'N/A' or ans == 'Unknown' or ans == 'No':
            continue

        fld["value"] = ans

        field_mapping[fld["name"]] = {"value": ans, "field_type": fld["type"], "field_name": fld["name"]}

fill_pa_form(input_pa_form, field_mapping, output_pa_form)
# Out:
# dict_items([])
